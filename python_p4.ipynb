# %%
try:
    import pandas as pd
    print("Python is installed")

    print(f"pandas version:{pd.__version__}")
except ImportError:
    print("Pandas is not installed")
# Out:
# Python is installed
# pandas version:2.3.3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\mahes\Desktop\python_projects\employee_attrition_performance.csv")

# %%
data
# Out:
#      employee_id  age  gender    education   department job_role  \
# 0       EMP00001   42  Female       Master      Finance  Role_22
# 1       EMP00002   35    Male       Master           HR   Role_8
# 2       EMP00003   40    Male          PhD        Legal   Role_1
# 3       EMP00004   35    Male  High School          R&D  Role_15
# 4       EMP00005   47    Male     Bachelor      Finance  Role_11
# ...          ...  ...     ...          ...          ...      ...
# 9995    EMP09996   40    Male  High School  Engineering  Role_23
# 9996    EMP09997   28  Female          PhD          R&D  Role_15
# 9997    EMP09998   38    Male     Bachelor  Engineering  Role_18
# 9998    EMP09999   34  Female  High School  Engineering   Role_2
# 9999    EMP10000   34  Female          PhD        Legal  Role_27
#
#       monthly_salary  years_at_company  years_in_current_role  \
# 0             107433                 2                      0
# ...

# %% [markdown]
# **Let's Display The First Rows Of The Dataset**

# %%
data.head()
# Out:
#   employee_id  age  gender    education department job_role  monthly_salary  \
# 0    EMP00001   42  Female       Master    Finance  Role_22          107433
# 1    EMP00002   35    Male       Master         HR   Role_8           77660
# 2    EMP00003   40    Male          PhD      Legal   Role_1          114377
# 3    EMP00004   35    Male  High School        R&D  Role_15           79284
# 4    EMP00005   47    Male     Bachelor    Finance  Role_11           95933
#
#    years_at_company  years_in_current_role  performance_score  ...  overtime  \
# 0                 2                      0                3.4  ...       Yes
# 1                 4                      0                3.4  ...       Yes
# 2                 3                      0                4.1  ...        No
# 3                 2                      1                2.9  ...        No
# 4                 1                      1                3.3  ...        No
#
# ...

# %% [markdown]
# **Let's Display The Last Rows Of The Dataset**

# %%
data.tail()
# Out:
#      employee_id  age  gender    education   department job_role  \
# 9995    EMP09996   40    Male  High School  Engineering  Role_23
# 9996    EMP09997   28  Female          PhD          R&D  Role_15
# 9997    EMP09998   38    Male     Bachelor  Engineering  Role_18
# 9998    EMP09999   34  Female  High School  Engineering   Role_2
# 9999    EMP10000   34  Female          PhD        Legal  Role_27
#
#       monthly_salary  years_at_company  years_in_current_role  \
# 9995           85575                 6                      2
# 9996          108003                 6                      2
# 9997           87503                 4                      1
# 9998           79382                 0                      0
# 9999          101594                 2                      2
#
#       performance_score  ...  overtime  distance_from_home_km  \
# 9995                3.2  ...        No                      4
# 9996                3.4  ...        No                      6
# ...

# %% [markdown]
# **Lets Check The Shape Of the dataset**

# %%
data.shape
# Out:
# (10000, 22)

# %%
print("Total No Of Rows:",data.shape[0])
print("Total No Of Columns:",data.shape[1])
# Out:
# Total No Of Rows: 10000
# Total No Of Columns: 22

# %% [markdown]
# **Now Drop All The Unwanted Columns**

# %%
data.columns
# Out:
# Index(['employee_id', 'age', 'gender', 'education', 'department', 'job_role',
#        'monthly_salary', 'years_at_company', 'years_in_current_role',
#        'performance_score', 'job_satisfaction', 'work_life_balance',
#        'overtime', 'distance_from_home_km', 'num_projects_last_year',
#        'training_hours_last_year', 'num_promotions',
#        'last_promotion_years_ago', 'stock_option_level',
#        'relationship_satisfaction', 'environment_satisfaction', 'attrition'],
#       dtype='object')

# %% [markdown]
# **Getting information about our dataset like total no of rows,total no of columns,datatype of each column
# and memory requirement**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   employee_id                10000 non-null  object
#  1   age                        10000 non-null  int64
#  2   gender                     10000 non-null  object
#  3   education                  10000 non-null  object
#  4   department                 10000 non-null  object
#  5   job_role                   10000 non-null  object
#  6   monthly_salary             10000 non-null  int64
#  7   years_at_company           10000 non-null  int64
#  8   years_in_current_role      10000 non-null  int64
#  9   performance_score          10000 non-null  float64
#  10  job_satisfaction           10000 non-null  float64
#  11  work_life_balance          10000 non-null  int64
#  12  overtime                   10000 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['employee_id', 'age', 'gender', 'education', 'department', 'job_role',
#        'monthly_salary', 'years_at_company', 'years_in_current_role',
#        'performance_score', 'job_satisfaction', 'work_life_balance',
#        'overtime', 'distance_from_home_km', 'num_projects_last_year',
#        'training_hours_last_year', 'num_promotions',
#        'last_promotion_years_ago', 'stock_option_level',
#        'relationship_satisfaction', 'environment_satisfaction', 'attrition'],
#       dtype='object')

# %% [markdown]
# **Now Drop All The Unwanted Columns**

# %%
data=data.drop(['performance_score','overtime', 'distance_from_home_km', 'num_projects_last_year','training_hours_last_year','num_promotions','last_promotion_years_ago','stock_option_level'
          ,'relationship_satisfaction'],axis=1)

# %%
data.columns
# Out:
# Index(['employee_id', 'age', 'gender', 'education', 'department', 'job_role',
#        'monthly_salary', 'years_at_company', 'years_in_current_role',
#        'job_satisfaction', 'work_life_balance', 'environment_satisfaction',
#        'attrition'],
#       dtype='object')

# %%
data
# Out:
#      employee_id  age  gender    education   department job_role  \
# 0       EMP00001   42  Female       Master      Finance  Role_22
# 1       EMP00002   35    Male       Master           HR   Role_8
# 2       EMP00003   40    Male          PhD        Legal   Role_1
# 3       EMP00004   35    Male  High School          R&D  Role_15
# 4       EMP00005   47    Male     Bachelor      Finance  Role_11
# ...          ...  ...     ...          ...          ...      ...
# 9995    EMP09996   40    Male  High School  Engineering  Role_23
# 9996    EMP09997   28  Female          PhD          R&D  Role_15
# 9997    EMP09998   38    Male     Bachelor  Engineering  Role_18
# 9998    EMP09999   34  Female  High School  Engineering   Role_2
# 9999    EMP10000   34  Female          PhD        Legal  Role_27
#
#       monthly_salary  years_at_company  years_in_current_role  \
# 0             107433                 2                      0
# ...

# %% [markdown]
# **Let's Check the employee_ids whose monthly salary is greater than or equal to 10000**

# %%
data[data['monthly_salary']>=10000][['employee_id','monthly_salary']]
# Out:
#      employee_id  monthly_salary
# 0       EMP00001          107433
# 1       EMP00002           77660
# 2       EMP00003          114377
# 3       EMP00004           79284
# 4       EMP00005           95933
# ...          ...             ...
# 9995    EMP09996           85575
# 9996    EMP09997          108003
# 9997    EMP09998           87503
# 9998    EMP09999           79382
# 9999    EMP10000          101594
#
# [10000 rows x 2 columns]

# %% [markdown]
# **Count Of female and male employees**

# %%
data['gender'].value_counts()
# Out:
# gender
# Male      4869
# Female    4724
# Other      407
# Name: count, dtype: int64

# %%
data
# Out:
#      employee_id  age  gender    education   department job_role  \
# 0       EMP00001   42  Female       Master      Finance  Role_22
# 1       EMP00002   35    Male       Master           HR   Role_8
# 2       EMP00003   40    Male          PhD        Legal   Role_1
# 3       EMP00004   35    Male  High School          R&D  Role_15
# 4       EMP00005   47    Male     Bachelor      Finance  Role_11
# ...          ...  ...     ...          ...          ...      ...
# 9995    EMP09996   40    Male  High School  Engineering  Role_23
# 9996    EMP09997   28  Female          PhD          R&D  Role_15
# 9997    EMP09998   38    Male     Bachelor  Engineering  Role_18
# 9998    EMP09999   34  Female  High School  Engineering   Role_2
# 9999    EMP10000   34  Female          PhD        Legal  Role_27
#
#       monthly_salary  years_at_company  years_in_current_role  \
# 0             107433                 2                      0
# ...

# %% [markdown]
# **Lets see the male and females salaries visually**

# %%
sns.boxplot(x='gender',y='monthly_salary',data=data)
# Out:
# <Axes: xlabel='gender', ylabel='monthly_salary'>

# %%
data[data['gender']=='Male'][['gender','monthly_salary']].sort_values(by='monthly_salary')
# Out:
#      gender  monthly_salary
# 8652   Male           40800
# 8635   Male           40874
# 7175   Male           40892
# 3834   Male           41753
# 6370   Male           42167
# ...     ...             ...
# 2194   Male          155402
# 6396   Male          157163
# 4286   Male          158837
# 2334   Male          159766
# 7446   Male          163489
#
# [4869 rows x 2 columns]

# %% [markdown]
# **Let's Check The Total Amount of Salary Credited to Employees**

# %%
data['monthly_salary'].sum()
# Out:
# np.int64(854223345)

# %% [markdown]
# **Let's See employees data who completed more than 3 years in company**

# %%
data[data['years_at_company']>=3]
# Out:
#      employee_id  age  gender    education   department job_role  \
# 1       EMP00002   35    Male       Master           HR   Role_8
# 2       EMP00003   40    Male          PhD        Legal   Role_1
# 13      EMP00014   28  Female     Bachelor          R&D   Role_5
# 14      EMP00015   42  Female       Master  Engineering  Role_45
# 15      EMP00016   56    Male       Master           HR  Role_12
# ...          ...  ...     ...          ...          ...      ...
# 9993    EMP09994   44  Female  High School           HR   Role_5
# 9994    EMP09995   39  Female       Master  Engineering  Role_31
# 9995    EMP09996   40    Male  High School  Engineering  Role_23
# 9996    EMP09997   28  Female          PhD          R&D  Role_15
# 9997    EMP09998   38    Male     Bachelor  Engineering  Role_18
#
#       monthly_salary  years_at_company  years_in_current_role  \
# 1              77660                 4                      0
# ...

# %% [markdown]
# **Let's check is there any null values in the data**

# %%
data.isnull().sum()
# Out:
# employee_id                 0
# age                         0
# gender                      0
# education                   0
# department                  0
# job_role                    0
# monthly_salary              0
# years_at_company            0
# years_in_current_role       0
# job_satisfaction            0
# work_life_balance           0
# environment_satisfaction    0
# attrition                   0
# dtype: int64

# %% [markdown]
# **Let's Check How many employees are not okay with the Environment in the office**

# %%
sum(data['environment_satisfaction']>=2)
# Out:
# 9023

# %% [markdown]
# **Check for the max performance of the dataset**

# %%
data.loc[data['performance_score'].idxmax()]
# Out:
# employee_id                  EMP01380
# age                                39
# gender                           Male
# education                      Master
# department                        R&D
# job_role                      Role_30
# monthly_salary                  93208
# years_at_company                    1
# years_in_current_role               1
# performance_score                 5.0
# job_satisfaction                  4.9
# work_life_balance                   4
# overtime                           No
# distance_from_home_km               4
# num_projects_last_year              4
# training_hours_last_year           23
# num_promotions                      0
# last_promotion_years_ago            1
# stock_option_level                  0
# relationship_satisfaction           1
# environment_satisfaction            3
# attrition                          No
# Name: 1379, dtype: object

# %% [markdown]
# **lets return the 10th row of the dataset**

# %%
data.loc[10]
# Out:
# employee_id                     EMP00011
# age                                   38
# gender                              Male
# education                         Master
# department                   Engineering
# job_role                          Role_8
# monthly_salary                    120335
# years_at_company                       0
# years_in_current_role                  0
# performance_score                    2.9
# job_satisfaction                     3.8
# work_life_balance                      3
# overtime                              No
# distance_from_home_km                  3
# num_projects_last_year                 2
# training_hours_last_year              75
# num_promotions                         0
# last_promotion_years_ago               0
# stock_option_level                     0
# relationship_satisfaction              3
# environment_satisfaction               1
# attrition                             No
# Name: 10, dtype: object

# %% [markdown]
# **Attrition Analysis-OverAll Attrition Rate**

# %%
data.columns
# Out:
# Index(['employee_id', 'age', 'gender', 'education', 'department', 'job_role',
#        'monthly_salary', 'years_at_company', 'years_in_current_role',
#        'job_satisfaction', 'work_life_balance', 'environment_satisfaction',
#        'attrition'],
#       dtype='object')

# %%
data['attrition'].value_counts(normalize=True)*100
# Out:
# attrition
# No     86.0
# Yes    14.0
# Name: proportion, dtype: float64

# %% [markdown]
# **Attrition By Department-Which department has highest attrition risk**

# %%
data.groupby('department')['attrition'].value_counts(normalize=True)
# Out:
# department   attrition
# Engineering  No           0.865566
#              Yes          0.134434
# Finance      No           0.846336
#              Yes          0.153664
# HR           No           0.868607
#              Yes          0.131393
# Legal        No           0.866345
#              Yes          0.133655
# Marketing    No           0.854456
#              Yes          0.145544
# Operations   No           0.869738
#              Yes          0.130262
# R&D          No           0.853896
#              Yes          0.146104
# Sales        No           0.854708
#              Yes          0.145292
# Name: proportion, dtype: float64

# %% [markdown]
# **Attrition by gender**

# %%
pd.crosstab(data['gender'],data['attrition'],normalize='index')*100
# Out:
# attrition         No        Yes
# gender
# Female     86.071126  13.928874
# Male       85.808174  14.191826
# Other      87.469287  12.530713

# %%
data.groupby('gender')['attrition'].value_counts(normalize=True)
# Out:
# gender  attrition
# Female  No           0.860711
#         Yes          0.139289
# Male    No           0.858082
#         Yes          0.141918
# Other   No           0.874693
#         Yes          0.125307
# Name: proportion, dtype: float64

# %% [markdown]
# **Salary Analysis-Average Salary By Department**

# %%
data.groupby('department')['monthly_salary'].mean().sort_values(ascending=False)
# Out:
# department
# Engineering    97781.350629
# R&D            95207.549513
# Finance        91906.258471
# Legal          88204.112721
# Sales          83137.469156
# Marketing      79809.749796
# Operations     75846.496426
# HR             71477.412274
# Name: monthly_salary, dtype: float64

# %% [markdown]
# **Salary Vs Attrition -Are low-paid employees leaving more?**

# %%
data.groupby('attrition')['monthly_salary'].mean()
# Out:
# attrition
# No     85530.436860
# Yes    84758.277143
# Name: monthly_salary, dtype: float64

# %% [markdown]
# **Let's Salary Destribution Visually**

# %%
import seaborn as sns

# %%
sns.histplot(data['monthly_salary'],kde=True)
# Out:
# <Axes: xlabel='monthly_salary', ylabel='Count'>

# %% [markdown]
# ### Experience & Growth Analysis
# #### Years at company vs attrition

# %%
data.groupby('attrition')['years_at_company'].mean()
# Out:
# attrition
# No     4.033837
# Yes    2.471429
# Name: years_at_company, dtype: float64

# %% [markdown]
# #### Are employees with low job satisfaction leaving? (Very critical for HR)

# %%
data.columns
# Out:
# Index(['employee_id', 'age', 'gender', 'education', 'department', 'job_role',
#        'monthly_salary', 'years_at_company', 'years_in_current_role',
#        'job_satisfaction', 'work_life_balance', 'environment_satisfaction',
#        'attrition'],
#       dtype='object')

# %%
data.groupby('attrition')['job_satisfaction'].mean()
# Out:
# attrition
# No     3.230267
# Yes    2.788214
# Name: job_satisfaction, dtype: float64

# %% [markdown]
# **Work-life balance impact**

# %%
data.groupby('work_life_balance')['attrition'].value_counts(normalize=True)
# Out:
# work_life_balance  attrition
# 1                  No           0.824111
#                    Yes          0.175889
# 2                  No           0.800603
#                    Yes          0.199397
# 3                  No           0.878564
#                    Yes          0.121436
# 4                  No           0.877412
#                    Yes          0.122588
# Name: proportion, dtype: float64
